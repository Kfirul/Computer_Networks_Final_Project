# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('C:\\Users\\USER\\Desktop\\Data_For_Network_Project\\OneImageWeb.csv')
data = data.drop(['No.'] , axis=1)
# Filter rows containing "TCP" in the protocol column

data
# Out:
#          Time        Source   Destination Protocol  Length  \
# 0   10.741826     10.0.2.15  157.240.0.60  TLSv1.2     118
# 1   10.742726  157.240.0.60     10.0.2.15      TCP      60
# 2   11.541241     10.0.2.15  157.240.0.60  TLSv1.2     143
# 3   11.541493     10.0.2.15  157.240.0.60  TLSv1.2     143
# 4   11.541785  157.240.0.60     10.0.2.15      TCP      60
# ..        ...           ...           ...      ...     ...
# 86  30.381755  157.240.0.60     10.0.2.15      TCP      60
# 87  30.510913     10.0.2.15  157.240.0.60  TLSv1.2     162
# 88  30.511693  157.240.0.60     10.0.2.15      TCP      60
# 89  30.670184  157.240.0.60     10.0.2.15  TLSv1.2     149
# 90  30.670221     10.0.2.15  157.240.0.60      TCP      54
#
#                                                  Info
# 0                                    Application Data
# 1    443  >  40100 [ACK] Seq=1 Ack=65 Win=65535 Len=0
# 2                                    Application Data
# ...

# %%
# Filter rows containing "TCP" in the Protocol column
tcp_data = data[data['Protocol'] == 'TCP']

# Extract the "Length" column and calculate the Ethernet payload lengths
eth_payload_lengths = tcp_data['Length']  # Subtract Ethernet header length (14 bytes)

# Plot the graph
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(eth_payload_lengths)
# plt.axhline(y=1500, color='r', linestyle='--', label='Max Ethernet Frame Size (1500 bytes)')
plt.xlabel('Packet Index')
plt.ylabel('Ethernet Payload Length')
plt.title('Ethernet Payload Length Graph')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
tcp_data
# Out:
#          Time        Source   Destination Protocol  Length  \
# 1   10.742726  157.240.0.60     10.0.2.15      TCP      60
# 4   11.541785  157.240.0.60     10.0.2.15      TCP      60
# 5   11.541785  157.240.0.60     10.0.2.15      TCP      60
# 7   11.697967  157.240.0.60     10.0.2.15      TCP      60
# 9   11.721275     10.0.2.15  157.240.0.60      TCP      54
# 11  11.731295     10.0.2.15  157.240.0.60      TCP      54
# 13  11.879860     10.0.2.15  157.240.0.60      TCP      54
# 14  11.880671     10.0.2.15  157.240.0.60      TCP      74
# 15  11.950710  157.240.0.60     10.0.2.15      TCP      60
# 16  11.950787     10.0.2.15  157.240.0.60      TCP      54
# 18  11.951588  157.240.0.60     10.0.2.15      TCP      60
# 20  12.022858     10.0.2.15  157.240.0.60      TCP      54
# 22  12.022960     10.0.2.15  157.240.0.60      TCP      54
# 25  12.031778  157.240.0.60     10.0.2.15      TCP      60
# 27  12.032361  157.240.0.60     10.0.2.15      TCP      60
# ...
