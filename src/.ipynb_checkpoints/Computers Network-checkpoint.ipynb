# %% [markdown]
# # <center><h1><u>Computers Network Project</u></h1></center>

# %% [markdown]
#  ## Presented by:
#   * **Kfir Zilbernagel** 209367366
#   * **Roy Ofer** 208953513

# %% [markdown]
# # Task Definition:
# <span style="font-size: large;">
#
# To record multiple messaging (IM) groups using a traffic application, each with distinct characteristics (messages, images, videos, etc.), and to determine if we can classify each group based on time and size.
#
# A portion of the task involves determining whether the attacking individual is affiliated with a certain group
#
# For the task execution, we chose WhatsApp Web as the messaging (IM) platform, and Wireshark as the software for data analysis.
#
# To accurately characterize messages and avoid unnecessary noise, we acquired a SIM card to ensure clean data without interference from other WhatsApp groups' applications or messages.

# %% [markdown]
# ## About Whatsapp encryption while using WireShark:
# <span style="font-size: large;">
#
# * Strong Encryption: WhatsApp messages are heavily locked with encryption.
#
# * Secret Keys: Only your device and the recipient's device can unlock these messages.
#
# * Unreadable Content: When captured in Wireshark, the message content is like a secret code – unreadable without the right keys.
#
# * Privacy Protection: This encryption keeps your messages safe from prying eyes, even if they see the captured packets.
#
# So, even though you might see the packets in Wireshark, the actual messages are safe and private due to this strong encryption.

# %% [markdown]
# <span style="font-size: large;">
#
# To select the appropriate filtering in Wireshark and identify the relevant packets that best serve our task while filtering out remaining noise, we chose the following filtering approach:
#
# 1.  We identified the IP of WhatsApp Web using the `nslookup` code (note that it changes).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-size: large;">
#
# 2.We selected our personal destination IP using the `ifconfig` command in the terminal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-size: large;">
#
# We have arrived at additional conclusions, which we will elaborate on below.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  <span style="font-size: large;">
#
#  A function that generates a graph displaying packets by their times compared to their respective lengths.

# %%
def create_packet_length_bar_graph(data, xlabel, ylabel, title, color='black'):
    # Convert 'Time' column to numeric (seconds)
    data['Time'] = pd.to_numeric(data['Time'])

    # Extract the "Length" column and calculate the Ethernet payload lengths
    data_length = data['Length'] 

    # Create the bar graph
    plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
    plt.bar(data['Time'], data_length, color=color)  # Use 'Time' column for x-axis
    plt.xlabel(xlabel)  # Set x-axis label
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.show()

# %% [markdown]
# <span style="font-size: large;">
#
# Now let's present the data table.

# %%
# Read the CSV file
data_MixTextVideo = pd.read_csv("../resources/CsvFiles/MixTextVideo.csv")
data_MixTextVideo = data_MixTextVideo.drop(['No.'] , axis=1)

data_MixTextVideo
# Out:
#            Time        Source   Destination Protocol  Length  \
# 0      4.574620     10.0.2.15  157.240.0.60  TLSv1.2     124
# 1      4.575098  157.240.0.60     10.0.2.15      TCP      60
# 2      4.740392  157.240.0.60     10.0.2.15  TLSv1.2     126
# 3      4.740450     10.0.2.15  157.240.0.60      TCP      54
# 4      6.295326     10.0.2.15  157.240.0.60  TLSv1.2     118
# ..          ...           ...           ...      ...     ...
# 806  115.746863  157.240.0.60     10.0.2.15      TCP      60
# 807  115.793791     10.0.2.15  157.240.0.60  TLSv1.2     156
# 808  115.794387  157.240.0.60     10.0.2.15      TCP      60
# 809  115.988090  157.240.0.60     10.0.2.15  TLSv1.2     143
# 810  115.988144     10.0.2.15  157.240.0.60      TCP      54
#
#                                                   Info
# 0                                     Application Data
# 1     443  >  56326 [ACK] Seq=1 Ack=71 Win=65535 Len=0
# 2                                     Application Data
# 3    56326  >  443 [ACK] Seq=71 Ack=73 Win=64022 Len=0
# 4                                     Application Data
# ..                                                 ...
# 806  443  >  56326 [ACK] Seq=8857 Ack=1641 Win=6553...
# 807                                   Application Data
# 808  443  >  56326 [ACK] Seq=8857 Ack=1743 Win=6553...
# 809                                   Application Data
# 810  56326  >  443 [ACK] Seq=1743 Ack=8946 Win=6278...
#
# [811 rows x 6 columns]

# %% [markdown]
# <span style="font-size: large;">
# We initiated a project focused on determining the nature of content within WhatsApp packets, discerning whether they contain text, video, audio, or files. Our initial approach involves exploring filtering techniques, beginning with a test involving only text and video content to identify any observable differences.
#
#
#
# </span>

# %%
create_packet_length_bar_graph(data_MixTextVideo, 'Time (seconds)', 'Packet Length', 'Mix Text Video Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
# After looking at the graph, which shows packets over time, We can see there's a big group of large packets and a smaller group of smaller packets. Since We sent a video first, followed by a text message, and repeated this sequence several times, it seems like the bigger packets represent videos and the smaller packets represent text.
#
#
#
#
#
#
# </span>

# %% [markdown]
# <span style="font-size: large;">
# After examining Wireshark, we observed that text messages don't seem to be sent through the QUIC protocol. Consequently, we will attempt to filter based solely on this protocol to identify the packet clusters containing videos.
#
# </span>

# %%
# Convert 'Time' column to numeric (seconds)
data_MixTextVideo['Time'] = pd.to_numeric(data_MixTextVideo['Time'])
data_MixTextVideo =data_MixTextVideo[data_MixTextVideo['Protocol'] == 'QUIC']
# Extract the "Length" column and calculate the Ethernet payload lengths
data_Video_Length = data_MixTextVideo['Length']  

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(data_MixTextVideo['Time'], data_Video_Length,color ="black")  # Use 'Time' column for x-axis
plt.xlabel('Time (seconds)')  # Set x-axis label
plt.ylabel('Packet Length')
plt.title('Videos Packets Length Overtime')
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="font-size: large;">
#
#
# Given that in the test we conducted, we sent 3 text messages and 3 video clips, it's noticeable that we were able to isolate the packets corresponding to the videos, which are displayed over time.
#
#
#
#
# </span>

# %% [markdown]
# <span style="font-size: large;">
#
# We then proceeded to conduct an experiment that involved sending text, an image, and a video in order to identify each type of content.
#
#
#
#
#
# </span>

# %%
# Read the CSV file
data_MixTIV = pd.read_csv("../resources/CsvFiles/MixTIV.csv")
data_MixTIV = data_MixTIV.drop(['No.'] , axis=1)

data_MixTIV
# Out:
#           Time        Source   Destination Protocol  Length  \
# 0     0.000000     10.0.2.15  157.240.0.60  TLSv1.2     124
# 1     0.000605  157.240.0.60     10.0.2.15      TCP      60
# 2     0.161704  157.240.0.60     10.0.2.15  TLSv1.2     126
# 3     0.161740     10.0.2.15  157.240.0.60      TCP      54
# 4     6.165160  157.240.0.60     10.0.2.15  TLSv1.2     285
# ..         ...           ...           ...      ...     ...
# 573  92.707530  157.240.0.60     10.0.2.15      TCP      60
# 574  92.769408     10.0.2.15  157.240.0.60  TLSv1.2     157
# 575  92.769784  157.240.0.60     10.0.2.15      TCP      60
# 576  92.933642  157.240.0.60     10.0.2.15  TLSv1.2     144
# 577  92.933685     10.0.2.15  157.240.0.60      TCP      54
#
#                                                   Info
# 0                                     Application Data
# 1     443  >  56326 [ACK] Seq=1 Ack=71 Win=65535 Len=0
# 2                                     Application Data
# 3    56326  >  443 [ACK] Seq=71 Ack=73 Win=62780 Len=0
# 4                                     Application Data
# ..                                                 ...
# 573  443  >  56326 [ACK] Seq=11382 Ack=2211 Win=655...
# 574                                   Application Data
# 575  443  >  56326 [ACK] Seq=11382 Ack=2314 Win=655...
# 576                                   Application Data
# 577  56326  >  443 [ACK] Seq=2314 Ack=11472 Win=627...
#
# [578 rows x 6 columns]

# %%
create_packet_length_bar_graph(data_MixTIV, 'Time (seconds)', 'Packet Length', 'Mix Text Images Videos Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
#
# It's evident that the current filtering approach we initially considered didn't assist us in distinguishing between images and videos. The number of packets on the graph seems similar for both. In contrast, text packets appear smaller on the graph, although certainty is limited as noise might also be recorded. Consequently, we will begin attempting to identify each content type separately by attributing specific characteristics to each group, aiming to arrive at alternative conclusions.
#
#
#
#
# </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#   ## QUIC
# <span style="font-size: large;">
#
# WhatsApp uses QUIC, capturing messages like videos or images in Wireshark involves:
# * Capture Packets: Monitor network traffic in Wireshark.
# * Identify QUIC: Spot QUIC packets via UDP and port numbers.
# * QUIC Handshake: Detect initial handshake for secure connection.
# * Data Exchange: Observe data packets containing messages.
# * Analyze Frames: View metadata of messages, but content stays encrypted.
# * Encryption: It's crucial to note that the content of messages, images, and videos exchanged through WhatsApp is encrypted by default, whether using QUIC or other protocols. Encryption ensures the privacy and security of the communication. Therefore, the actual content of videos, images, and messages remains unreadable and encrypted in the captured packets.

# %% [markdown]
# ## Additional helper functions

# %% [markdown]
# <span style="font-size: large;">
#
#  A function that generates a graph displaying packets sent at Groups withe threshold compared to their respective lengths.

# %%
def create_group_packet_bar_graph(data, xlabel, ylabel, title,threshold):

    # Group the data by delay intervals and sum the packet lengths
    data_grouped = data.groupby(data['Delay'].gt(threshold).cumsum())['Length'].sum()

    # Create the bar graph
    plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
    data_grouped.plot(kind='bar', x=data_grouped.index, y=data_grouped.values)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.grid(True)
    plt.show()

# %% [markdown]
# <span style="font-size: large;">
# PDF graph is a graphical representation that shows the distribution of continuous data along a specific range of values. It is commonly used in statistics and data analysis to visualize how the values are spread out within a dataset.
#
# Our PDF graph represents the distribution of inter-arrival times (time gaps between consecutive events) for network packet arrivals.
# The x-axis would show the inter-arrival times in seconds.
# The y-axis shows the probability density of each inter-arrival time.
# By plotting a histogram (a bar graph that shows the frequency of different inter-arrival time ranges) and fitting an exponential distribution curve over it, you're visually comparing the empirical data distribution with a theoretical distribution, allowing you to assess how well the theoretical model matches your actual data.
#
# </span>

# %%
def generate_and_plot_pdf_with_exponential_fit(df, bins=10):

    df_cleaned = df.dropna(subset=['Delay'])
    
    counts, bin_edges = np.histogram(df_cleaned['Delay'], bins=bins, density=True)
    
    # Convert counts to probabilities
    pdf = counts / sum(counts)
    
    plt.figure(figsize=(10, 6))
    
    # Plotting the outline of the histogram using plt.step
    plt.step(bin_edges[:-1], pdf, where='post', color='blue', lw=2, label='PDF')
    
    # Estimate lambda (rate parameter) from the data
    lambd = 1. / np.mean(df['Delay'])
    
    # Compute the bin width from the first two bin edges
    bin_width = bin_edges[1] - bin_edges[0]
    
    # Adjust the scale_factor with respect to bin_width
    scale_factor = max(pdf) / (lambd * np.exp(-lambd * bin_edges[np.argmax(pdf)]))
    
    # Create x values for the fitted exponential curve
    x = np.linspace(0, max(bin_edges), 500)
    
    # Calculate exponential distribution values using the estimated lambda
    y = scale_factor * lambd * np.exp(-lambd * x)
    
    plt.plot(x, y, color='red', lw=2, label='Fitted Exponential Distribution')
    
    plt.xlabel('Inter-Arrival Time')
    plt.ylabel('Density')
    plt.title('PDF of Inter-Arrival Time and Fitted Exponential Distribution')
    plt.legend()
    plt.grid(True)
    
    plt.show()

# %% [markdown]
# <span style="font-size: large;">
#
# A function that create data frame
# We will add a column named "Delay" that describes the differences between the various recorded packets.
#
#
#
# </span>

# %%
def create_df(path):
    df= pd.read_csv(path)
    df = df.drop(['No.'] , axis=1)
    df['Delay'] = pd.to_numeric(df['Time']).diff()
    return df

# %% [markdown]
# ## Images

# %% [markdown]
# <span style="font-size: large;">
# We will commence working on a group that exclusively contains images, without any other types of content.
#
# </span>

# %%
data_Images=create_df("../resources/CsvFiles/Images.csv")
data_Images
# Out:
#             Time        Source Destination Protocol  Length  \
# 0       0.170136  157.240.0.60   10.0.2.15  TLSv1.2     112
# 1       1.627378  157.240.0.60   10.0.2.15  TLSv1.2     118
# 2       1.730907  157.240.0.60   10.0.2.15  TLSv1.3     266
# 3       1.816041  157.240.0.60   10.0.2.15  TLSv1.3     299
# 4       1.817875  157.240.0.60   10.0.2.15  TLSv1.3      98
# ...          ...           ...         ...      ...     ...
# 1486  177.341475  213.57.24.97   10.0.2.15     QUIC    1274
# 1487  177.341475  213.57.24.97   10.0.2.15     QUIC    1274
# 1488  177.341475  213.57.24.97   10.0.2.15     QUIC     282
# 1489  177.378110  213.57.24.97   10.0.2.15     QUIC      90
# 1490  180.791075  157.240.0.60   10.0.2.15  TLSv1.2     126
#
#                                                    Info         Delay
# 0                                      Application Data           NaN
# 1                                      Application Data  1.457242e+00
# 2     Server Hello, Change Cipher Spec, Application ...  1.035288e-01
# 3                    Application Data, Application Data  8.513434e-02
# 4                                      Application Data  1.833529e-03
# ...                                                 ...           ...
# 1486                            Protected Payload (KP0)  1.004890e-04
# 1487                            Protected Payload (KP0)  1.100000e-07
# 1488                            Protected Payload (KP0)  2.100001e-08
# 1489                            Protected Payload (KP0)  3.663472e-02
# 1490                                   Application Data  3.412965e+00
#
# [1491 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now, after recording about 3 minutes of sending images, during which we sent a total of 12 images, we will present the graph illustrating the packets that were sent over time.
#
#
#
#
# </span>

# %%
create_packet_length_bar_graph(data_Images, 'Time (seconds)', 'Packet Length', 'Images Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
#
# We can observe that it's not entirely possible to distinguish between images and noise since the packets are scattered. We will attempt to define a specific threshold and assume that based on this difference, there's a need to group packets together, assuming they belong to the same image that was sent. Subsequently, we will sum up each group separately and try to filter out small packets that have been grouped.
#
#
#
#
# </span>

# %%
create_group_packet_bar_graph(data_Images,'Group','Sum of Packet Lengths',f'Groups of Image Packets',0.1)

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# In the generated graph, it's clear that there are 12 distinct groups of packets, corresponding to the images. Concurrently, there is still minimal noise present, but based on the size, it's apparent that the noise packets do not contain the image data.
#
#
#
# </span>

# %%
generate_and_plot_pdf_with_exponential_fit(data_Images, bins=100)

# %% [markdown]
# <span style="font-size: large;">
#
# It can be inferred from observing the graph that packets sent with very low time intervals have a significantly high probability of being closely related to each other.

# %% [markdown]
# <span style="font-size: large;">
#
# We will save the average size of the images for the following graphs.
# We want to save only what we defined as an image and not calculate the noises as they will affect the average calculation.
# Therefore, from observing the graph, we will select only the sizes above of the min group size.
#
# </span>

# %%
data_grouped = data_Images.groupby(data_Images['Delay'].gt(0.1).cumsum())['Length'].sum()
size_of_min_group = data_grouped[38]  
size_of_min_group
# Out:
# 39738

# %% [markdown]
# <span style="font-size: large;">
#
# After we calculated the minimum of the packets, we will calculate their average.
# We will use it later after we calculating the rest of the averages

# %%
average_of_Images = data_grouped[data_grouped > size_of_min_group].mean()
average_of_Images
# Out:
# 156796.54545454544

# %% [markdown]
# # Files

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# We will now verify if the filtering approach we found for images also works for files. We will record a session in WhatsApp where only files are being sent, with a similar size distribution and no significant deviations. The recording will span around 3 minutes and include the transmission of 10 files.
#
#
#
# </span>

# %%
data_Files=create_df("../resources/CsvFiles/Files.csv")
data_Files
# Out:
#             Time        Source Destination Protocol  Length  \
# 0       0.082465  157.240.0.60   10.0.2.15  TLSv1.2     788
# 1       0.370200  157.240.0.60   10.0.2.15     QUIC    1274
# 2       0.370200  157.240.0.60   10.0.2.15     QUIC     251
# 3       0.372108  157.240.0.60   10.0.2.15     QUIC      90
# 4       0.372358  157.240.0.60   10.0.2.15     QUIC     122
# ...          ...           ...         ...      ...     ...
# 4945  173.342415  157.240.0.60   10.0.2.15     QUIC    1274
# 4946  173.342415  157.240.0.60   10.0.2.15     QUIC    1274
# 4947  173.395569  157.240.0.60   10.0.2.15     QUIC      90
# 4948  173.412412  157.240.0.60   10.0.2.15     QUIC      90
# 4949  175.034538  157.240.0.60   10.0.2.15  TLSv1.2     126
#
#                                                    Info         Delay
# 0                    Application Data, Application Data           NaN
# 1     Initial, SCID=961d00321409a208, PKN: 15326337,...  2.877349e-01
# 2                      Handshake, SCID=961d00321409a208  3.910000e-07
# 3                               Protected Payload (KP0)  1.907908e-03
# 4                               Protected Payload (KP0)  2.496500e-04
# ...                                                 ...           ...
# 4945                            Protected Payload (KP0)  5.999999e-08
# 4946                            Protected Payload (KP0)  2.100001e-08
# 4947                            Protected Payload (KP0)  5.315436e-02
# 4948                            Protected Payload (KP0)  1.684304e-02
# 4949                                   Application Data  1.622126e+00
#
# [4950 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
# Let's first take a look at the graph that depicts the results based on the filtering we found, before we grouped the packets.
#
#
#
#
# </span>

# %%
create_packet_length_bar_graph(data_Files, 'Time (seconds)', 'Packet Length', 'Files Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
#
# We will now proceed to group the packets based on the time differences between them.
#
#
#
#
# </span>

# %%
create_group_packet_bar_graph(data_Files,'Group','Sum of Packet Lengths',f'Groups of Files Packets',0.1)

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now, after the grouping, we can clearly observe 10 dominant clusters, which represent the groups of packets containing data regarding the files we sent. Additionally, there are also very small clusters, which can be inferred as background noise that was recorded, containing no significant information about the files.
#
#
#
#
# </span>

# %%
generate_and_plot_pdf_with_exponential_fit(data_Files, bins=100)

# %% [markdown]
# <span style="font-size: large;">
#
# It can be inferred from observing the graph that packets sent with very low time intervals have a significantly high probability of being closely related to each other.

# %% [markdown]
# <span style="font-size: large;">
#
# We will save the average size of the files for the following graphs.
# We want to save only what we defined as an file and not calculate the noises as they will affect the average calculation.
# Therefore, from observing the graph, we will select only the sizes above the min group size.
#
# </span>

# %%
data_grouped = data_Files.groupby(data_Files['Delay'].gt(0.1).cumsum())['Length'].sum()

size_of_min_group = data_grouped[37]  
size_of_min_group
# Out:
# 306670

# %% [markdown]
# <span style="font-size: large;">
#
# After we calculated the minimum of the packets, we will calculate their average.

# %%
average_of_Files = data_grouped[data_grouped > size_of_min_group].mean()
average_of_Files
# Out:
# 651087.5555555555

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# It can be inferred that the filtering we discovered is effective here as well. We will proceed to the next group.
#
#
#
# </span>

# %% [markdown]
# # Videos

# %% [markdown]
# <span style="font-size: large;">
#
#
# We will now proceed to record the transmission of videos in a WhatsApp group. We recorded the group's activity for approximately 3 minutes, during which we sent 7 videos with varying sizes.
#
#
#
#
# </span>

# %%
data_Video=create_df("../resources/CsvFiles/Video.csv")
data_Video
# Out:
#              Time        Source Destination Protocol  Length  \
# 0        0.221994  157.240.0.60   10.0.2.15  TLSv1.2     128
# 1        0.244895  157.240.0.60   10.0.2.15  TLSv1.2     128
# 2       18.657686  157.240.0.60   10.0.2.15  TLSv1.2     466
# 3       18.821473  213.57.24.97   10.0.2.15     QUIC    1274
# 4       18.821474  213.57.24.97   10.0.2.15     QUIC     250
# ...           ...           ...         ...      ...     ...
# 14917  167.571204  157.240.0.60   10.0.2.15  TLSv1.2     126
# 14918  172.053599  157.240.0.60   10.0.2.15  TLSv1.2     112
# 14919  172.071647  157.240.0.60   10.0.2.15  TLSv1.2     149
# 14920  172.073397  157.240.0.60   10.0.2.15  TLSv1.2     143
# 14921  177.006386  157.240.0.60   10.0.2.15  TLSv1.2     127
#
#                                                     Info         Delay
# 0                                       Application Data           NaN
# 1                                       Application Data  2.290101e-02
# 2                     Application Data, Application Data  1.841279e+01
# 3      Initial, SCID=9d81000620eb1c51, PKN: 3474616, ...  1.637866e-01
# 4                       Handshake, SCID=9d81000620eb1c51  8.420000e-07
# ...                                                  ...           ...
# 14917                                   Application Data  2.115151e+00
# 14918                                   Application Data  4.482395e+00
# 14919                                   Application Data  1.804771e-02
# 14920                                   Application Data  1.750879e-03
# 14921                                   Application Data  4.932989e+00
#
# [14922 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# We can observe that in the data here, even after filtering, there are around 15,000 rows in the table compared to the other tables which were significantly smaller. This is because we sent heavy videos, which resulted in recording a lot more data points.
#
#
#
# </span>

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now we will present the graph of the Packets over time, without grouping them by the delays.
#
#
#
#
# </span>

# %%
create_packet_length_bar_graph(data_Video, 'Time (seconds)', 'Packet Length', 'Videos Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# The graph still doesn't make it clear which packets belong to the video and which packets are noise. Therefore, we will consolidate the packets based on time intervals.
#
#
#
# </span>

# %%
create_group_packet_bar_graph(data_Video,'Group','Sum of Packet Lengths',f'Groups of Videos Packets',0.1)

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# Now it's evident that there are 7 distinct groups of packets that are potential candidates to be the packets containing video data. Simultaneously, there are very small groups that can be inferred as noise.
#
# Given that there are exactly 7 significant groups, we can conclude that these are the groups representing the sent videos.
#
#
#
#
# </span>

# %%
generate_and_plot_pdf_with_exponential_fit(data_Video, bins=100)

# %% [markdown]
# <span style="font-size: large;">
#
# It can be inferred from observing the graph that packets sent with very low time intervals have a significantly high probability of being closely related to each other.

# %% [markdown]
# <span style="font-size: large;">
#
# We will save the average size of the videos for the following graphs.
# We want to save only what we defined as an video and not calculate the noises as they will affect the average calculation.
# Therefore, from observing the graph, we will select only the sizes above the min group size.
#
# </span>

# %%
data_grouped = data_Video.groupby(data_Video['Delay'].gt(0.1).cumsum())['Length'].sum()
size_of_min_group = data_grouped[3]  
size_of_min_group
# Out:
# 1593083

# %% [markdown]
# <span style="font-size: large;">
# After we calculated the minimum of the packets, we will calculate their average.

# %%
average_of_Videos = data_grouped[data_grouped > size_of_min_group].mean()
average_of_Videos
# Out:
# 2768994.0

# %% [markdown]
# # Text

# %% [markdown]
# <span style="font-size: large;">
#
#
# We will now proceed to record the transmission of Textss in a WhatsApp group. We recorded the group's activity for approximately 3 minutes, during which we sent 11 Texts with varying sizes.

# %%
data_Text=create_df("../resources/CsvFiles/Text.csv")
data_Text
# Out:
#           Time          Source Destination Protocol  Length  \
# 0     0.676755  157.240.221.60   10.0.2.15      TCP      60
# 1     0.834949  157.240.221.60   10.0.2.15  TLSv1.2     126
# 2     5.915235  157.240.221.60   10.0.2.15  TLSv1.2    1312
# 3     6.257159  157.240.221.60   10.0.2.15      TCP      60
# 4    18.481758  157.240.221.60   10.0.2.15      TCP    1402
# ..         ...             ...         ...      ...     ...
# 64  176.072205  157.240.221.60   10.0.2.15      TCP    1402
# 65  176.078074  157.240.221.60   10.0.2.15  TLSv1.2    1301
# 66  176.089224  157.240.221.60   10.0.2.15      TCP    2750
# 67  176.091838  157.240.221.60   10.0.2.15  TLSv1.2    1631
# 68  176.642348  157.240.221.60   10.0.2.15      TCP      60
#
#                                                  Info      Delay
# 0    443  >  36966 [ACK] Seq=1 Ack=71 Win=65535 Len=0        NaN
# 1                                    Application Data   0.158194
# 2                                    Application Data   5.080286
# 3   443  >  36966 [ACK] Seq=1331 Ack=162 Win=65535...   0.341925
# 4   443  >  36966 [PSH, ACK] Seq=1331 Ack=162 Win=...  12.224599
# ..                                                ...        ...
# 64  443  >  36966 [PSH, ACK] Seq=41291 Ack=1545 Wi...   0.005386
# 65                                   Application Data   0.005868
# 66  443  >  36966 [PSH, ACK] Seq=43886 Ack=1545 Wi...   0.011150
# 67                 Application Data, Application Data   0.002614
# 68  443  >  36966 [ACK] Seq=48159 Ack=1636 Win=655...   0.550510
#
# [69 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now we will present the graph of the Packets over time, without grouping them by the delays.

# %%
create_packet_length_bar_graph(data_Text, 'Time (seconds)', 'Packet Length', 'Texts Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
# The graph still doesn't make it clear which packets belong to the video and which packets are noise. Therefore, we will consolidate the packets based on time intervals.

# %%
create_group_packet_bar_graph(data_Text,'Group','Sum of Packet Lengths',f'Groups of Texts Packets',0.1)

# %%
generate_and_plot_pdf_with_exponential_fit(data_Text, bins=100)

# %% [markdown]
# <span style="font-size: large;">
#
# Unlike the previous message types, here the probability of packets with very low time intervals between them being closely related is relatively lower. This can be explained by the fact that text packets are shorter in length. As a result, the remaining "noise" is almost comparable to the size of the text packets, reducing the likelihood of close association between them.

# %% [markdown]
# <span style="font-size: large;">
#
# We will save the average size of the Texts for the following graphs.
# We want to save only what we defined as an video and not calculate the noises as they will affect the average calculation.
# Therefore, from observing the graph, we will select only the sizes above min group size.
#
# </span>

# %%
data_grouped = data_Text.groupby(data_Text['Delay'].gt(0.1).cumsum())['Length'].sum()
size_of_min_group = data_grouped[2]  
size_of_min_group
# Out:
# 1312

# %% [markdown]
# <span style="font-size: large;">
# After we calculated the minimum of the packets, we will calculate their average.

# %%
average_of_Text = data_grouped[data_grouped > size_of_min_group].mean()
average_of_Text
# Out:
# 4811.5

# %% [markdown]
# # Mix

# %% [markdown]
# <span style="font-size: large;">
#
# CCDF stands for "Complementary Cumulative Distribution Function." It's a statistical concept used to analyze and visualize the distribution of data in a dataset. The CCDF graph provides insight into the tail behavior of the distribution, which is particularly useful for understanding extreme values or rare events in the data.
#
# In a CCDF graph, the x-axis represents the values of the data (in this case, normalized message sizes), and the y-axis represents the probability that a value in the dataset is greater than or equal to the corresponding x-axis value.

# %%
def plot_ccdf(dataframes, labels, big_threshold=0.7):
    fig, ax = plt.subplots(figsize=(10, 6))
    for df, label in zip(dataframes, labels):
        # Sort and normalize the data
        sorted_vals = np.sort(df['Length'])
        normalized_vals = sorted_vals / max(sorted_vals)

        # Compute CDF and then CCDF
        cdf = np.arange(1, len(sorted_vals) + 1) / len(sorted_vals)
        ccdf = 1 - cdf
        
        plt.plot(normalized_vals, ccdf, label=label)
    
    plt.yscale('log')
    plt.xscale('log')
    plt.xlabel('Normalized Message Sizes')
    plt.ylabel('CCDF')
    plt.title('CCDF of Packets Size Distribution')
    plt.legend(loc="lower left")
    plt.show()
    return fig

# %%
dfs = [data_Images, data_Files, data_Video, data_Text]
labels = [ 'Images ', 'Files ', 'Videos ', 'Text ']

fig = plot_ccdf(dfs, labels)

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now that we've identified the characteristics of each group separately, let's try again to identify, from within a group where all types of messages are sent, which type of message was sent.
#
#
#
#
# </span>

# %% [markdown]
# <span style="font-size: large;">
#
#
# We will present the average graph in order to provide us with a better perspective to understand the sizes of each message type.
#
#
#
# </span>

# %%
import matplotlib.pyplot as plt

# Message types
message_types = ['Text', 'Image', 'File','Video']

# Average values
average_values = [average_of_Text, average_of_Images, average_of_Files,average_of_Videos]

plt.figure(figsize=(8, 5))  # Adjust the figure size as needed
plt.plot(message_types, average_values, marker='o', linestyle='-', color='orange')
plt.xlabel('Message Type')
plt.ylabel('Average Size')
plt.title('Average Sizes of Message Types')
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="font-size: large;">
#
# Let's start by sending different types of messages in the same sequence. We'll start with a small example where we send an image, then a file, and then a video twice in that order. We will then try to identify the types based on the sizes of the packets over time.
#
#
#
#
#
# </span>

# %%
data_Mix1=create_df("../resources/CsvFiles/MixTest.csv")
data_Mix1
# Out:
#             Time        Source Destination Protocol  Length  \
# 0       0.000000  157.240.0.60   10.0.2.15  TLSv1.2      93
# 1       7.287422  157.240.0.60   10.0.2.15  TLSv1.2      71
# 2       7.503120  213.57.24.97   10.0.2.15     QUIC    1274
# 3       7.503120  213.57.24.97   10.0.2.15     QUIC     250
# 4       7.503120  213.57.24.97   10.0.2.15     QUIC     122
# ...          ...           ...         ...      ...     ...
# 8779  130.241281  213.57.24.97   10.0.2.15     QUIC      90
# 8780  130.241410  213.57.24.97   10.0.2.15     QUIC    1274
# 8781  130.241499  213.57.24.97   10.0.2.15     QUIC      90
# 8782  130.241605  213.57.24.97   10.0.2.15     QUIC    1274
# 8783  130.241817  213.57.24.97   10.0.2.15     QUIC      90
#
#                                                    Info         Delay
# 0                                      Application Data           NaN
# 1                                      Application Data  7.287422e+00
# 2     Initial, SCID=b68100094b0971d5, PKN: 7703410, ...  2.156973e-01
# 3                      Handshake, SCID=b68100094b0971d5  4.210000e-07
# 4                               Protected Payload (KP0)  3.000000e-08
# ...                                                 ...           ...
# 8779                            Protected Payload (KP0)  8.562000e-05
# 8780                            Protected Payload (KP0)  1.292720e-04
# 8781                            Protected Payload (KP0)  8.887700e-05
# 8782                            Protected Payload (KP0)  1.059590e-04
# 8783                            Protected Payload (KP0)  2.124080e-04
#
# [8784 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
#
#
# Now we'll present a graph of the packets over time after recording the transmission for approx 2 minutes.
#
#
# </span>

# %%
create_packet_length_bar_graph(data_Mix1, 'Time (seconds)', 'Packet Length', 'Mix Packets- Image-File-Video Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
# The graph still doesn't make it clear which packets belong to the video and which packets are noise. Therefore, we will consolidate the packets based on time intervals.

# %%
create_group_packet_bar_graph(data_Mix1,'Group','Sum of Packet Lengths',f'Groups of Mix Packets- Image-File-Video',0.5)

# %% [markdown]
# <span style="font-size: large;">
#
#
# After the consolidation of packets that we performed, it's now clear to identify the different sizes. The first group represents an image, the second group represents a file, and the third group represents a video, in that order.
#
# As expected, the size of the video packets' group is significantly larger than the other types, just as we anticipated.
#
#
#
#
# </span>

# %% [markdown]
# <span style="font-size: large;">
#
# Now we will conduct an experiment where we send text, image, file, and video messages, not in any specific order. We will record WhatsApp for 3 minutes while sending these different types randomly.
#
#
#
#
#
# </span>

# %% [markdown]
# <span style="font-size: large;">
#
#
# Certainly, here as well, we will need to add the DELAY column.
#
#
#
#
# </span>

# %%
# Read the CSV file into a DataFrame
data_Mix2 = pd.read_csv("../resources/CsvFiles/Mix.csv")
# data_Mix2 = pd.read_csv('C:\\NetworkProject\\CsvFiles\\Mix.csv')
data_Mix2 = data_Mix2.drop(['No.'] , axis=1)
data_Mix2['Delay'] = pd.to_numeric(data_Mix2['Time']).diff()
data_Mix2
# Out:
#             Time        Source Destination Protocol  Length  \
# 0       0.167277  157.240.0.60   10.0.2.15  TLSv1.2     112
# 1      13.762455  157.240.0.60   10.0.2.15  TLSv1.2    1102
# 2      14.124700  157.240.0.60   10.0.2.15     QUIC    1274
# 3      14.125920  157.240.0.60   10.0.2.15     QUIC     251
# 4      14.125921  157.240.0.60   10.0.2.15     QUIC      90
# ...          ...           ...         ...      ...     ...
# 7196  177.487015  213.57.24.97   10.0.2.15     QUIC    1274
# 7197  177.487015  213.57.24.97   10.0.2.15     QUIC     666
# 7198  177.487016  213.57.24.97   10.0.2.15     QUIC    1274
# 7199  177.487016  213.57.24.97   10.0.2.15     QUIC     922
# 7200  179.873733  157.240.0.60   10.0.2.15  TLSv1.2     126
#
#                                                    Info         Delay
# 0                                      Application Data           NaN
# 1                                      Application Data  1.359518e+01
# 2     Initial, SCID=ab1d00c412adb583, PKN: 10860662,...  3.622456e-01
# 3                      Handshake, SCID=ab1d00c412adb583  1.219718e-03
# 4                               Protected Payload (KP0)  5.010000e-07
# ...                                                 ...           ...
# 7196                            Protected Payload (KP0)  5.810000e-07
# 7197                            Protected Payload (KP0)  4.110000e-07
# 7198                            Protected Payload (KP0)  6.110000e-07
# 7199                            Protected Payload (KP0)  9.999999e-08
# 7200                                   Application Data  2.386717e+00
#
# [7201 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now we will create a graph of the packets over time using the provided data.
#
#
#
#
# </span>

# %%
create_packet_length_bar_graph(data_Mix2, 'Time (seconds)', 'Packet Length', 'Mix Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# Again, the graph here is still not organized, and we will need to consolidate the packets based on timestamps.
#
#
#
# </span>

# %%
create_group_packet_bar_graph(data_Mix2,'Group','Sum of Packet Lengths',f'Groups of Mix Packets- Image-File-Video',0.1)

# %% [markdown]
# <span style="font-size: large;">
#
# Considering all the findings we've made so far and based on the average sizes of each data type, we will try to color the appropriate group according to its type.

# %%
# Set the threshold interval
threshold = 0.1  # seconds

# Group the data by delay intervals and sum the packet lengths
data_grouped = data_Mix2.groupby(data_Mix2['Delay'].gt(threshold).cumsum())['Length'].sum()


# Determine color categories based on conditions
color_categories = []
for value in data_grouped:
    if average_of_Text - average_of_Text/1.08 < value < average_of_Text + average_of_Text/1.08:
        color_categories.append('red')
    elif average_of_Images - average_of_Images/1.08 < value < average_of_Images + average_of_Images/1.08:
        color_categories.append('green')
    elif average_of_Files - average_of_Files/1.08 < value < average_of_Files + average_of_Files/1.08:
        color_categories.append('deepskyblue')
    else:
        color_categories.append('purple')

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
ax = data_grouped.plot(kind='bar', color=color_categories, label='Sum of Lengths')
ax.set_xlabel('Group')
ax.set_ylabel('Packet Length')
ax.set_title(f'Group packets of mix messages')

# Create custom legend
legend_labels = {
    'red': 'Text',
    'green': 'Image',
    'deepskyblue': 'File',
    'purple': 'Video'
}
handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='', label=label)
           for color, label in legend_labels.items()]

ax.legend(handles=handles)
ax.grid(True)
plt.show()

# %% [markdown]
# <span style="font-size: large;">
#
#
#
# Now, we can see that we've colored the groups accordingly:
# - Text in red (appears very small, but can be seen in groups 19 and 34)
# - Image in green
# - File in blue
# - Video in purple
#
# The classification has indeed succeeded, as it exactly matches the order of messages sent in the WhatsApp group.
#
# We'll attach a partial image from the group that depicts the types of files sent in the recorded transmission.
#
#
#
# </span>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <span style="font-size: large;">
#
# We will now present the data of the first packet that was sent, and it appears to match the time the file was sent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-size: large;">
#
# We will provide additional examples.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Noise

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now we'll try to identify messages that were sent in WhatsApp, given deliberate "noise" we introduce – for example, playing a Spotify video in the background. We'll attempt to locate the WhatsApp messages and discern the Spotify activity.
#
#
#
#
# </span>

# %%
data_Noise=create_df("../resources/CsvFiles/Noise.csv")
data_Noise
# Out:
#             Time         Source      Destination Protocol  Length  \
# 0       0.000000      10.0.2.15  239.255.255.250     SSDP     215
# 1       0.482335      10.0.2.15    35.186.224.25      UDP     118
# 2       0.485348      10.0.2.15    35.186.224.25      UDP     114
# 3       0.489133      10.0.2.15    35.186.224.25      UDP     114
# 4       0.506115  35.186.224.25        10.0.2.15      UDP      69
# ...          ...            ...              ...      ...     ...
# 6144  189.260382  35.186.224.40        10.0.2.15      TCP      60
# 6145  189.345408  35.186.224.40        10.0.2.15  TLSv1.2      94
# 6146  189.345452      10.0.2.15    35.186.224.40      TCP      54
# 6147  193.168705      10.0.2.15    213.57.24.219  TLSv1.2     858
# 6148  193.169334  213.57.24.219        10.0.2.15      TCP      60
#
#                                                    Info     Delay
# 0                                  M-SEARCH * HTTP/1.1        NaN
# 1                                  58286  >  443 Len=76  0.482335
# 2                                  42965  >  443 Len=72  0.003013
# 3                                  42965  >  443 Len=72  0.003785
# 4                                  443  >  58286 Len=27  0.016982
# ...                                                 ...       ...
# 6144  443  >  56102 [ACK] Seq=168309 Ack=302 Win=655...  0.000939
# 6145                                   Application Data  0.085026
# 6146  56102  >  443 [ACK] Seq=302 Ack=168349 Win=655...  0.000044
# 6147                                   Application Data  3.823253
# 6148  443  >  50672 [ACK] Seq=3324058 Ack=17619 Win=...  0.000629
#
# [6149 rows x 7 columns]

# %% [markdown]
# <span style="font-size: large;">
#
#
# Now we will create a graph of the packets over time using the provided data.

# %%
create_packet_length_bar_graph(data_Noise, 'Time (seconds)', 'Packet Length', 'Noise Packets Length Overtime', color='black')

# %% [markdown]
# <span style="font-size: large;">
#
# We will identify the IP address belonging to WhatsApp and the IP address belonging to Spotify.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="font-size: large;">
#
# Now let's color the graph according to the distribution of the IP addresses we found.

# %%
target_ip1 = '35.186.224.25'
target_ip2 = '157.240.252.60'
# Create a mask for each source IP address
mask_ip1 = data_Noise['Source'] == target_ip1
mask_ip2 = data_Noise['Source'] == target_ip2
data_Noise_Length = data_Noise['Length'] 

# Create the bar graph
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.bar(data_Noise['Time'][mask_ip1], data_Noise_Length.loc[mask_ip1], color='lime', label='spotify')
plt.bar(data_Noise['Time'][mask_ip2], data_Noise_Length.loc[mask_ip2], color='magenta', label='Whatsapp')
plt.xlabel('Time (seconds)')
plt.ylabel('Packet Length')
plt.title('Files Packets Length Overtime by Source IP')
plt.legend()  # Show legend indicating colors and labels
plt.grid(True)
plt.show()

# %% [markdown]
# <span style="font-size: large;">
#
# We can see that we have now color-coded the graph based on the IP addresses belonging to Spotify and the IP address linked to WhatsApp.
#
# It's evident that initially, there are multiple packets being sent from Spotify as it's in the process of downloading the song we selected. Since we began playing the song first, there's a brief pause of a few seconds before actions related to WhatsApp start. Only after that delay do we start to observe WhatsApp-related activities appearing on the graph.

# %%
create_group_packet_bar_graph(data_Noise,'Group','Sum of Packet Lengths',f'Groups of Packets with Spotify noise',0.1)

# %% [markdown]
# <span style="font-size: large;">
#
# Now, after we've grouped the packets based on the delay and additionally colored the packets according to the average video size, we can discern and identify which packets belong to the video sent via WhatsApp and which packets belong to Spotify.

# %%
# Set the threshold interval
threshold = 0.1  # seconds

# Group the data by delay intervals and sum the packet lengths
data_grouped = data_Noise.groupby(data_Noise['Delay'].gt(threshold).cumsum())['Length'].sum()

# Determine color categories based on conditions
color_categories = []
for value in data_grouped:
    if average_of_Videos - average_of_Videos/1.2 < value < average_of_Videos + average_of_Videos/1.2:
            color_categories.append('magenta')
    else:
        color_categories.append('lime')

plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
ax = data_grouped.plot(kind='bar', color=color_categories, label='Sum of Lengths')
ax.set_xlabel('Group')
ax.set_ylabel('Packet Length')
ax.set_title(f'Group packets of Spotify and Whatsapp ')

# Create custom legend
legend_labels = {
    'magenta': 'Whatsapp',
    'lime': 'Spotify'
}
handles = [plt.Line2D([0], [0], color=color, marker='o', linestyle='', label=label)
           for color, label in legend_labels.items()]

ax.legend(handles=handles)
ax.grid(True)
plt.show()

# %% [markdown]
# # Conclusions
#
# <span style="font-size: large;">
#
# Research Findings:
# After examining network traffic for different WhatsApp groups, distinctive characteristics can be deduced for each group. These encompass the volume of group engagement, message types transmitted, and variations in activity intensity based on timing. Can these outlined strategies in the paper be utilized to pinpoint the groups an individual is partaking in?
#
#
# Certainly. Through scrutinizing network behaviors like this, it is plausible to authenticate suspect involvement within a specific group and gauge their degree of interaction within it. This necessitates access to the suspect's network data and employing a attacker within the WhatsApp groups where the person is suspected of participation.
#
# The objectives underlying the methods delineated in the article are as follows:
# - Discern "incidents" by analyzing temporal packet density and the capacity to combine multiple packets into a single message occurrence.
# - Monitor administrators and members across groups by contrasting user-specific traffic patterns or event densities with the group's overall traffic.
# - Monitor the principal traffic coursing through a group.
#
# We aimed to construct graphs mirroring group traffic as expounded in the article. This groundwork aligns fittingly with their methodologies. Our script compiled packets traversing the network, partitioned them into messages anchored in server communication, and produced graphs for each communication channel, categorizing packets deemed "sufficiently proximate" to form a solitary message occurrence.
#
# To draw conclusions about active participants, we matched suspected individuals' traffic against our eavesdropped group traffic. If the suspect receives messages from diverse groups, we considered this noise and focused on correlating message patterns with our target group's traffic. If a noteworthy proportion of messages align, it is conceivable that the individual is actively engaged in the group.
#
#
# However, when dealing with scenarios where the suspect engages in multiple groups, definitively attributing a message to a specific group becomes challenging due to encryption. Therefore, the first step is determining group participation. We scrutinize whether the suspect's network data encompasses the target group's traffic and subsequently appraise their activity percentage within the group.
#
# The research also seeks to track the central traffic coursing through a group. To discern the nature of traffic, we delve deeply into recordings and endeavor to ascertain whether message density signifies substantial shared files or distinctively spaced text messages. Leveraging data from the article can enable us to probabilistically infer the nature of messages being shared.
#
# In essence, our investigation corroborates the assertions made by the authors. Encryption within messaging apps, such as WhatsApp, inadequately conceals users' activities, rendering it feasible for adept individuals to trail users and groups via network analysis. To uphold users' privacy, techniques should be deployed to minimize the transparency of network traffic, aligning with the suggestions outlined in the article.
